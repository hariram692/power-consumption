# %%
import pandas as pd
df = pd.read_csv('household_power_consumption.txt', sep=';', header=0, low_memory=False, infer_datetime_format=True, parse_dates={'datetime':[0,1]}, index_col=['datetime'],na_values=['nan','?'])

df.shape
df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3
# datetime
# ...

# %%
df.tail()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2010-11-26 19:18:00                1.152                  0.104   237.72
# 2010-11-26 19:19:00                1.136                  0.106   238.14
# 2010-11-26 19:20:00                1.130                  0.112   239.07
# 2010-11-26 19:21:00                1.124                  0.110   238.36
# 2010-11-26 19:22:00                1.110                  0.080   238.62
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2010-11-26 19:18:00               4.8             0.0             0.0
# 2010-11-26 19:19:00               4.8             0.0             0.0
# 2010-11-26 19:20:00               4.8             0.0             0.0
# 2010-11-26 19:21:00               4.6             0.0             0.0
# 2010-11-26 19:22:00               4.6             0.0             0.0
#
#                      Sub_metering_3
# datetime
# ...

# %%
df
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
# ...                                  ...                    ...      ...
# 2010-11-26 19:18:00                1.152                  0.104   237.72
# 2010-11-26 19:19:00                1.136                  0.106   238.14
# 2010-11-26 19:20:00                1.130                  0.112   239.07
# 2010-11-26 19:21:00                1.124                  0.110   238.36
# 2010-11-26 19:22:00                1.110                  0.080   238.62
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
df.shape
# Out:
# (2075159, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2075159 entries, 2006-12-16 17:24:00 to 2010-11-26 19:22:00
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Global_active_power    float64
#  1   Global_reactive_power  float64
#  2   Voltage                float64
#  3   Global_intensity       float64
#  4   Sub_metering_1         float64
#  5   Sub_metering_2         float64
#  6   Sub_metering_3         float64
# dtypes: float64(7)
# memory usage: 126.7 MB

# %%
df.isnull()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                False                  False    False
# 2006-12-16 17:25:00                False                  False    False
# 2006-12-16 17:26:00                False                  False    False
# 2006-12-16 17:27:00                False                  False    False
# 2006-12-16 17:28:00                False                  False    False
# ...                                  ...                    ...      ...
# 2010-11-26 19:18:00                False                  False    False
# 2010-11-26 19:19:00                False                  False    False
# 2010-11-26 19:20:00                False                  False    False
# 2010-11-26 19:21:00                False                  False    False
# 2010-11-26 19:22:00                False                  False    False
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
df.dropna(inplace =True)
df.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
df.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.049180e+06           2.049180e+06  2.049180e+06
# mean          1.091603e+00           1.237179e-01  2.408400e+02
# std           1.057314e+00           1.127229e-01  3.239992e+00
# min           7.600000e-02           0.000000e+00  2.232000e+02
# 25%           3.080000e-01           4.800000e-02  2.389900e+02
# 50%           6.020000e-01           1.000000e-01  2.410100e+02
# 75%           1.528000e+00           1.940000e-01  2.428900e+02
# max           1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.049180e+06    2.049180e+06    2.049180e+06    2.049180e+06
# mean       4.627707e+00    1.121978e+00    1.298550e+00    6.458763e+00
# std        4.444478e+00    6.153176e+00    5.822165e+00    8.437239e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
df.var()
# Out:
# Global_active_power       1.117914
# Global_reactive_power     0.012706
# Voltage                  10.497547
# Global_intensity         19.753388
# Sub_metering_1           37.861578
# Sub_metering_2           33.897604
# Sub_metering_3           71.187004
# dtype: float64

# %%
X=df[['Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3']]
y=df['Global_active_power']

# %%
X.head()
# Out:
#                      Global_reactive_power  Voltage  Global_intensity  \
# datetime
# 2006-12-16 17:24:00                  0.418   234.84              18.4
# 2006-12-16 17:25:00                  0.436   233.63              23.0
# 2006-12-16 17:26:00                  0.498   233.29              23.0
# 2006-12-16 17:27:00                  0.502   233.74              23.0
# 2006-12-16 17:28:00                  0.528   235.68              15.8
#
#                      Sub_metering_1  Sub_metering_2  Sub_metering_3
# datetime
# 2006-12-16 17:24:00             0.0             1.0            17.0
# 2006-12-16 17:25:00             0.0             1.0            16.0
# 2006-12-16 17:26:00             0.0             2.0            17.0
# 2006-12-16 17:27:00             0.0             1.0            17.0
# 2006-12-16 17:28:00             0.0             1.0            17.0

# %%
y.head()
# Out:
# datetime
# 2006-12-16 17:24:00    4.216
# 2006-12-16 17:25:00    5.360
# 2006-12-16 17:26:00    5.374
# 2006-12-16 17:27:00    5.388
# 2006-12-16 17:28:00    3.666
# Name: Global_active_power, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[ 2.61066849, -1.85185127,  3.098743  , -0.18234133, -0.05127821,
#          1.24937078],
#        [ 2.77035212, -2.2253091 ,  4.13373537, -0.18234133, -0.05127821,
#          1.13084857],
#        [ 3.32037351, -2.33024766,  4.13373537, -0.18234133,  0.12047924,
#          1.24937078],
#        ...,
#        [-0.10395323, -0.54629209,  0.03876558, -0.18234133, -0.22303567,
#         -0.76550682],
#        [-0.12169586, -0.7654285 , -0.00623409, -0.18234133, -0.22303567,
#         -0.76550682],
#        [-0.38783524, -0.68518136, -0.00623409, -0.18234133, -0.22303567,
#         -0.76550682]])

# %%
df.shape
# Out:
# (2049180, 7)

# %% [markdown]
# IMPUTING DATA :

# %%
import numpy as np
# fill missing values with a value at the same time one day ago
def fill_missing(values):
    one_day = 60 * 24
    for row in range(values.shape[0]):
        for col in range(values.shape[1]):
            if np.isnan(values[row, col]):
                values[row, col] = values[row - one_day, col]
# fill missing
fill_missing(df.values)

# %%
df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3
# datetime
# ...

# %%
# add a column for for the remainder of sub metering
values = df.values
df['sub_metering_4'] = (values[:,0] * 1000 / 60) - (values[:,4] + values[:,5] + values[:,6])
# save updated dataset
df.to_csv('household_power_consumption.csv')

# %%
df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3  sub_metering_4
# datetime
# ...

# %%
# resample minute data to total for each day
from pandas import read_csv
# load the new file
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
# resample data to daily
daily_groups = dataset.resample('D')
daily_data = daily_groups.sum()

# %%
dataset.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3  sub_metering_4
# datetime
# ...

# %%
daily_data.head()
# Out:
#             Global_active_power  Global_reactive_power    Voltage  \
# datetime
# 2006-12-16             1209.176                 34.922   93552.53
# 2006-12-17             3390.460                226.006  345725.32
# 2006-12-18             2203.826                161.792  347373.64
# 2006-12-19             1666.194                150.942  348479.01
# 2006-12-20             2225.748                160.998  348923.61
#
#             Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3  \
# datetime
# 2006-12-16            5180.8             0.0           546.0          4926.0
# 2006-12-17           14398.6          2033.0          4187.0         13341.0
# 2006-12-18            9247.2          1063.0          2621.0         14018.0
# 2006-12-19            7094.0           839.0          7602.0          6197.0
# 2006-12-20            9313.0             0.0          2648.0         14063.0
#
#             sub_metering_4
# datetime
# 2006-12-16    14680.933333
# ...

# %%
daily_data.shape
# Out:
# (1442, 8)

# %%
X_daily=daily_data[['Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3','sub_metering_4']]
y_daily=daily_data['Global_active_power']

# %%
X_daily.head()
# Out:
#             Global_reactive_power    Voltage  Global_intensity  \
# datetime
# 2006-12-16                 34.922   93552.53            5180.8
# 2006-12-17                226.006  345725.32           14398.6
# 2006-12-18                161.792  347373.64            9247.2
# 2006-12-19                150.942  348479.01            7094.0
# 2006-12-20                160.998  348923.61            9313.0
#
#             Sub_metering_1  Sub_metering_2  Sub_metering_3  sub_metering_4
# datetime
# 2006-12-16             0.0           546.0          4926.0    14680.933333
# 2006-12-17          2033.0          4187.0         13341.0    36946.666667
# 2006-12-18          1063.0          2621.0         14018.0    19028.433333
# 2006-12-19           839.0          7602.0          6197.0    13131.900000
# 2006-12-20             0.0          2648.0         14063.0    20384.800000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# resample data to yearly
year_groups = dataset.resample('A')
year_data = year_groups.sum()

# %%
X_year=year_data[['Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3']]
y_year=year_data['Global_active_power']

# %%
plt.figure(figsize = (18,10))
plt.title("Yearly Global_reactive_power ")
year_data['Global_reactive_power'].plot(kind = 'bar', color = 'royalblue')
# Out:
# <Axes: title={'center': 'Yearly Global_reactive_power '}, xlabel='datetime'>

# %% [markdown]
# Computing the data by resampling the data according to MONTHS :

# %%
# resample data to monthly
month_data = dataset.resample('M').sum()
month_data.shape
X_month=month_data[['Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3', 'sub_metering_4']]
y_month=month_data['Global_active_power']

# %%
month_data.shape
# Out:
# (48, 8)

# %%
plt.figure(figsize = (18,10))
plt.title("Monthly Global_reactive_power ")
month_data['Global_reactive_power'].plot(kind = 'bar', color = 'mediumslateblue')
# Out:
# <Axes: title={'center': 'Monthly Global_reactive_power '}, xlabel='datetime'>

# %%
plt.figure(figsize = (18,10))
plt.title("Monthly Global_active_power ")
y_month.plot(kind = 'bar', color = 'lightcoral')
# Out:
# <Axes: title={'center': 'Monthly Global_active_power '}, xlabel='datetime'>

# %% [markdown]
# BOX PLOTS :

# %%
import seaborn as sns
plt.figure(figsize=(15,12))
plt.title('Box Plot representation')
sns.boxplot(data = month_data)
# Out:
# <Axes: title={'center': 'Box Plot representation'}>

# %%
label = ['Global_reactive_power', 'Global_active_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3']
for i in range(7):
    sns.boxplot(data = month_data[label[i]])
    plt.show()

# %% [markdown]
# Data Representation :

# %%
sns.jointplot(x='Global_active_power',y='Global_reactive_power',data=month_data,kind='kde',color='fuchsia')

# %%
sns.jointplot(x='Global_active_power',y='Global_reactive_power',data=month_data,kind='reg',color='hotpink')

# %%
sns.pairplot(month_data)

# %%
sns.set_style("darkgrid")
g = sns.PairGrid(data = month_data , y_vars= 'Global_active_power', x_vars = ['Voltage', 'Global_intensity','Global_reactive_power'], height=6)
g.map(sns.regplot, color = 'firebrick')

# %%
sns.set_style("darkgrid")
g = sns.PairGrid(data = month_data , y_vars= 'Global_active_power', x_vars = ['Sub_metering_1','Sub_metering_2','Sub_metering_3','sub_metering_4'], height=6)
g.map(sns.regplot, color = 'black')

# %%
sns.set_style("darkgrid")
g = sns.PairGrid(data = year_data , y_vars= 'Global_active_power', x_vars = ['Sub_metering_1','Sub_metering_2','Sub_metering_3','sub_metering_4'], height=6)
g.map(sns.regplot, color = 'crimson')

# %%
correlation = month_data.corr(method='pearson')
columns = correlation.nlargest(10, 'Global_active_power').index
columns
# Out:
# Index(['Global_active_power', 'Global_intensity', 'sub_metering_4',
#        'Sub_metering_3', 'Sub_metering_1', 'Sub_metering_2', 'Voltage',
#        'Global_reactive_power'],
#       dtype='object')

# %% [markdown]
# Hence , we eliminate no features as the correlation shows

# %%
# resample data to monthly
month_data = dataset.resample('M').mean()
month_data.shape
X_month=month_data[['Global_reactive_power','Voltage','Global_intensity','Sub_metering_1','Sub_metering_2','Sub_metering_3']]
y_month=month_data['Global_active_power']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X_month);

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_month, y_month, test_size=0.2,  random_state=42)

# %%
X_train.columns
# Out:
# Index(['Global_reactive_power', 'Voltage', 'Global_intensity',
#        'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3'],
#       dtype='object')

# %%
 y_test
# Out:
# datetime
# 2009-03-31    1.226735
# 2010-04-30    1.027295
# 2009-02-28    1.247568
# 2010-07-31    0.721068
# 2008-12-31    1.275189
# 2010-01-31    1.430525
# 2007-12-31    1.626474
# 2008-07-31    0.794781
# 2007-04-30    0.891189
# 2009-01-31    1.410202
# Name: Global_active_power, dtype: float64

# %%
X_month.var()
# Out:
# Global_reactive_power    0.000480
# Voltage                  2.425404
# Global_intensity         1.482805
# Sub_metering_1           0.114114
# Sub_metering_2           0.151165
# Sub_metering_3           2.355524
# dtype: float64

# %%
X_test.var()
# Out:
# Global_reactive_power    0.000556
# Voltage                  2.268705
# Global_intensity         1.414497
# Sub_metering_1           0.146103
# Sub_metering_2           0.128614
# Sub_metering_3           2.688478
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X_train,y_train)
y_pred = linreg.predict(X_test)
from sklearn.metrics import r2_score
print(r2_score(y_test , y_pred))
print('Testing score: ',linreg.score(X_test,y_test))
print('Training Score: ',linreg.score(X_train,y_train))
# Out:
# 0.9998455765169112
# Testing score:  0.9998455765169112
# Training Score:  0.9998444540339005

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
rf = RandomForestRegressor(max_depth=2, random_state=0)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print('Mean Squared Error: ', mean_squared_error(y_test, y_pred))
print('Training Score: ', rf.score(X_train, y_train))
print('Testing score: ', rf.score(X_test, y_test))
# Out:
# Mean Squared Error:  0.006059163185561553
# Training Score:  0.9409519743684285
# Testing score:  0.9237293359047247

# %%
from sklearn.ensemble import AdaBoostRegressor
adb = AdaBoostRegressor(rf, n_estimators=300)
adb.fit(X_train, y_train)
y_pred = adb.predict(X_test)
print('Mean Squared Error: ', mean_squared_error(y_test, y_pred))
print('Training Score: ', adb.score(X_train, y_train))
print('Testing score: ', adb.score(X_test, y_test))
# Out:
# Mean Squared Error:  0.003694416547144553
# Training Score:  0.9852736271121596
# Testing score:  0.9534959540012498

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV
clf = RandomForestRegressor()

# %%
param = {'bootstrap': [True, False],
'max_depth': [5,10, None],
'min_samples_leaf': [1, 2, 4],
'min_samples_split': [2, 5, 10],
'n_estimators': [50,100]}

# %%
grid_search = GridSearchCV(clf,param_grid = param,cv = 5)

# %%
random_search = RandomizedSearchCV(clf, param_distributions=param,
                                  n_iter=10, cv=5)

# %%
regr = RandomForestRegressor(bootstrap= True,
 max_depth= None,
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 20)

# %%
regr = RandomForestRegressor(bootstrap= True,
 max_depth= None,
 min_samples_leaf= 1,
 min_samples_split= 2,
 n_estimators= 20)

# %%
regr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=20)

# %%
regr.score(X_train,y_train) ,regr.score(X_test,y_test)
# Out:
# (0.9686274849375689, 0.8995538250519768)

# %%
pred = regr.predict(X_test)

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("rf.pkl","wb")
pickle.dump(rf , pickle_out)
pickle_out.close()

# %%
import pickle
filename = 'power.sav'
pickle.dump(rf , open(filename, 'wb'))
# loading the saved model
loaded_model = pickle.load(open('power.sav', 'rb'))
